# %% [markdown]
# ## This workbook uses the class file for analysis

# %%
#ORB strategy 
# Getting the intraday data on any stock
# Build the strategy 
# 
import pandas as pd
import yfinance as yf

# %%
#Getting 30 days data 
#x=input("Please select some valid stock for analy")
intraday30_data = yf.download(tickers="MSFT",
 period="1mo",
 interval="15m",auto_adjust=True)
intraday30_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2021-05-05 09:30:00-04:00  248.735001  249.339996  248.365005  249.089996
# 2021-05-05 09:45:00-04:00  249.266006  249.279999  248.520004  248.619995
# 2021-05-05 10:00:00-04:00  248.679993  248.759995  247.610001  247.940002
# 2021-05-05 10:15:00-04:00  247.940002  248.210007  247.390106  248.110001
# 2021-05-05 10:30:00-04:00  248.120300  248.729996  248.000000  248.460007
#
#                             Volume
# Datetime
# 2021-05-05 09:30:00-04:00  2397387
# 2021-05-05 09:45:00-04:00  3386113
# 2021-05-05 10:00:00-04:00   892130
# 2021-05-05 10:15:00-04:00   683094
# 2021-05-05 10:30:00-04:00   645445

# %%
from Classes.ORB import ORB

y=ORB(intraday30_data)

df=y.get_ORB_parameters()

df.head()
# Out:
# /home/david/Documents/GitHub/DataScience/Classes/ORB.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.ORB_parameters.Date[index]      = intraday_data.index.date[0]
# /home/david/Documents/GitHub/DataScience/Classes/ORB.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.ORB_parameters.ORB_High[index]  = intraday_data.iloc[0].High
# /home/david/Documents/GitHub/DataScience/Classes/ORB.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#           Date    ORB_High     ORB_Low  Buy_trigger  Short_trigger  \
# 0   2021-05-05  249.339996  248.365005     0.000000     247.940002
# 1   2021-05-06  246.580002  244.949997   247.149994       0.000000
# 2   2021-05-07  252.580002  251.279999   253.260101       0.000000
# 3   2021-05-10  251.330002  249.360001   251.380005     249.001205
# 4   2021-05-11  245.000000  242.570099   245.164001       0.000000
# 5   2021-05-12  243.880005  242.139999     0.000000     241.460007
# 6   2021-05-13  243.190002  241.419998   243.279999       0.000000
# 7   2021-05-14  248.639999  245.490005   248.759995       0.000000
# 8   2021-05-17  246.589996  245.059998     0.000000     244.169998
# 9   2021-05-18  246.410004  245.330002     0.000000     245.318100
# 10  2021-05-19  241.212601  239.110001   241.220001       0.000000
# 11  2021-05-20  246.369995  243.860001   246.506500       0.000000
# 12  2021-05-21  248.309998  247.039993     0.000000     246.760193
# ...
